# %% [markdown]
# <a href="https://colab.research.google.com/github/SSSHAH2002/AutoMobile/blob/main/AUTOMobile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
automobile = pd.read_csv('/content/automobile_data.csv')

# %%
automobile.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
auto = automobile.copy()

# %%
#check unique in make(brand)
auto["make"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
auto.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
auto.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
x = auto.isnull()
sns.heatmap(x, yticklabels = False, cbar = False, cmap='viridis')
plt.show()

# %%
auto.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2            164.00         audi       gas        std         four
# 4          2            164.00         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1            158.00         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1            158.00         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
auto.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
#total number of car in each brand
total_no_car_eachbrand=auto["make"].value_counts().reset_index(name="total_number")

# %%
total_no_car_eachbrand
# Out:
#              make  total_number
# 0          toyota            32
# 1          nissan            18
# 2           mazda            17
# 3      mitsubishi            13
# 4           honda            13
# 5      volkswagen            12
# 6          subaru            12
# 7          peugot            11
# 8           volvo            11
# 9           dodge             9
# 10  mercedes-benz             8
# 11            bmw             8
# 12           audi             7
# 13       plymouth             7
# 14           saab             6
# 15        porsche             5
# 16          isuzu             4
# 17         jaguar             3
# 18      chevrolet             3
# 19    alfa-romero             3
# 20        renault             2
# 21        mercury             1

# %%
#total number of car in each brand
plt.bar(total_no_car_eachbrand['make'],total_no_car_eachbrand['total_number'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observation:

# %% [markdown]
# Toyota is most selling brand

# %%
#Replace  the data of price ('?',0 )
auto["price"]=auto["price"].replace('?',0)

# %%
#change the data_type of price (object to int )

auto['price'] = auto['price'].astype('int64')

# %%
#embark_town=df.groupby(['embark_town','sex'])['fare'].sum().round().astype(int).reset_index()

# %%
#total number of cars spend total money on each brand
group_one = auto.groupby(['make'])[ 'price'].sum().reset_index()

# %%
print(group_one)
# Out:
#              make   price
# 0     alfa-romero   46495
# 1            audi  107155
# 2             bmw  208950
# 3       chevrolet   18021
# 4           dodge   70879
# 5           honda  106401
# 6           isuzu   17833
# 7          jaguar  103800
# 8           mazda  181099
# 9   mercedes-benz  269176
# 10        mercury   16503
# 11     mitsubishi  120117
# 12         nissan  187482
# 13         peugot  170380
# 14       plymouth   55744
# 15        porsche  125602
# 16        renault   19190
# 17           saab   91340
# 18         subaru  102495
# 19         toyota  316346
# 20     volkswagen  120930
# 21          volvo  198695

# %%
# bar plot
#plt.figure(figsize=(4,3))
#color_bar = ['lightblue', 'blue', 'purple']
#plt.bar(embark_town['embark_town'],embark_town['fare'],color=color_bar)
#plt.title('Total fare of each embark_town',color='Blue')
#plt.xlabel('embark_town',color='Red')
#plt.ylabel('Total fare',color='green')

#plt.show()

# %%
#total number of cars spend total money on each brand

plt.bar(auto['make'],auto['price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observation:

# %% [markdown]
# High earning source is Mercedes-benz

# %%
auto.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
auto['fuel-type'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
#car which fuel is used
fuel_type = auto['fuel-type'].value_counts().reset_index(name='total_number')
print(fuel_type)
# Out:
#   fuel-type  total_number
# 0       gas           185
# 1    diesel            20

# %%
#car which fuel is used
plt.bar(fuel_type['fuel-type'],fuel_type['total_number'])
plt.show()

# %% [markdown]
# Observation:

# %% [markdown]
# Most of cars are using fuel type is Gas

# %%
#df.groupby('customer_id')['enterprise_id'].count().sort_values(ascending=False)

# %%
auto.groupby('make')['num-of-doors'].count()
# Out:
# make
# alfa-romero       3
# audi              7
# bmw               8
# chevrolet         3
# dodge             9
# honda            13
# isuzu             4
# jaguar            3
# mazda            17
# mercedes-benz     8
# mercury           1
# mitsubishi       13
# nissan           18
# peugot           11
# plymouth          7
# porsche           5
# renault           2
# saab              6
# subaru           12
# toyota           32
# volkswagen       12
# volvo            11
# Name: num-of-doors, dtype: int64

# %%
groupThree=auto.groupby(['make'])['body-style'].value_counts().reset_index(name="total")
groupThree
# Out:
#              make   body-style  total
# 0     alfa-romero  convertible      2
# 1     alfa-romero    hatchback      1
# 2            audi        sedan      5
# 3            audi    hatchback      1
# 4            audi        wagon      1
# 5             bmw        sedan      8
# 6       chevrolet    hatchback      2
# 7       chevrolet        sedan      1
# 8           dodge    hatchback      5
# 9           dodge        sedan      3
# 10          dodge        wagon      1
# 11          honda    hatchback      7
# 12          honda        sedan      5
# 13          honda        wagon      1
# 14          isuzu        sedan      3
# 15          isuzu    hatchback      1
# 16         jaguar        sedan      3
# 17          mazda    hatchback     10
# 18          mazda        sedan      7
# 19  mercedes-benz        sedan      4
# 20  mercedes-benz      hardtop      2
# 21  mercedes-benz  convertible      1
# 22  mercedes-benz        wagon      1
# 23        mercury    hatchback      1
# ...

# %%
SNS=sns.barplot(x='make',hue='body-style',
               y='total',data=groupThree)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observation:

# %% [markdown]
# Toyota's hatchback body type car is mostly selling

# %%
auto.head(44)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2            164.00         audi       gas        std
# 4           2            164.00         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1            158.00         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1            158.00         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2            192.00          bmw       gas        std
# 11          0            192.00          bmw       gas        std
# 12          0            188.00          bmw       gas        std
# ...

# %%
auto['peak-rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', '?', '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
auto['peak-rpm']=auto['peak-rpm'].replace('?',np.NaN)

# %%
auto.groupby(['make'])['peak-rpm'].value_counts()
# Out:
# make           peak-rpm
# alfa-romero    5000         3
# audi           5500         7
# bmw            4250         3
#                5400         3
#                5800         2
# chevrolet      5400         2
#                5100         1
# dodge          5500         7
#                5000         2
# honda          5800         5
#                6000         5
#                5500         2
#                4800         1
# isuzu          5400         2
#                4800         1
#                5000         1
# jaguar         4750         2
#                5000         1
# mazda          5000         6
#                4800         5
#                6000         4
#                4200         1
#                4650         1
# mercedes-benz  4350         4
#                4500         2
#                4750         2
# mercury        5000         1
# mitsubishi     5500         7
#                5000         6
# nissan         5200        17
# ...

# %%
auto['peak-rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', nan, '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
auto['peak-rpm'].isnull().sum()
# Out:
# 2

# %%
auto['peak-rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', nan, '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
auto['peak-rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', nan, '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
auto.head(49)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2            164.00         audi       gas        std
# 4           2            164.00         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1            158.00         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1            158.00         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2            192.00          bmw       gas        std
# 11          0            192.00          bmw       gas        std
# 12          0            188.00          bmw       gas        std
# ...

# %%
#auto["price"]=auto["price"].replace('?',0)

auto['peak-rpm']=auto['peak-rpm'].replace('nan',0)

# %%
auto['fuel-system'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
groupsix = auto['fuel-system'].value_counts().reset_index(name='total')
groupsix
# Out:
#   fuel-system  total
# 0        mpfi     94
# 1        2bbl     66
# 2         idi     20
# 3        1bbl     11
# 4        spdi      9
# 5        4bbl      3
# 6         mfi      1
# 7        spfi      1

# %%
#graph represent the which fuel system is mostly used
plt.bar(groupsix['fuel-system'],groupsix['total'])
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# Observation:

# %% [markdown]
# MOstly cars using MPFI fuel system

# %%
groupsix['total'].dtype
# Out:
# dtype('int64')

# %%
auto['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', '?', '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
auto.drop_duplicates()
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2            164.00         audi       gas        std
# 4            2            164.00         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1             95.00        volvo       gas        std
# 201         -1             95.00        volvo       gas      turbo
# 202         -1             95.00        volvo       gas        std
# 203         -1             95.00        volvo    diesel      turbo
# 204         -1             95.00        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
auto['horsepower'].replace('?',0)
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: object

# %%
auto['horsepower'].
# Out:
#   File "<ipython-input-120-2e2e95d766f4>", line 1
#     auto['horsepower'].
#                        ^
# SyntaxError: invalid syntax
